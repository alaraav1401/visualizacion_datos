# %% [markdown]
# ## Clase 1 - Introducción a Python

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# ### Cargando las librerias

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.43156596, 0.65697009, 0.79625094, 0.17268693, 0.77959697,
#        0.97236051, 0.36867308, 0.24541563, 0.46107719, 0.40603004,
#        0.71558885, 0.10936091, 0.15610959, 0.30799972, 0.86080406,
#        0.51833104, 0.37750515, 0.70525123, 0.02313447, 0.2706038 ,
#        0.09702787, 0.85959405, 0.58911515, 0.68982249, 0.33809175,
#        0.59665031, 0.37908608, 0.96364299, 0.15423238, 0.6452949 ,
#        0.11563812, 0.2428296 , 0.54399054, 0.79647695, 0.69476456,
#        0.24631534, 0.32504752, 0.58546432, 0.07796859, 0.62896124,
#        0.78739445, 0.37438551, 0.79363463, 0.11190478, 0.49359317,
#        0.42732822, 0.62223509, 0.24836649, 0.52329896, 0.6336252 ])

# %%
# %ls
# Out:
# 00_00_binder.ipynb                    02_02_basic_math.ipynb
# 00_00_primer_pasos.ipynb              datasets/
# 01_01_data_types.ipynb                README.md
# 01_02_read_iloc_unique_groupby.ipynb  requirements.txt
# 02_00_data_wrangling.ipynb            Untitled.ipynb
# 02_01_null_display.ipynb

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ### Tipos de datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_numbers/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi,3/5,4.0,'nombre',True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(False)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
    print(x,'es igual o mayor que',y)
# Out:
# 16 es igual o mayor que 8

# %%
unalista = [True,6<5,1==3,None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ### El uso de for (loop)

# %%
for element in unalista:
    print(element,'\t',type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# ### lista

# %%
unalista = ['first','second','third','fourth','fifth','sixth']
unalista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
#unalista.sort()
#unalista

# %%
unalista[:1]
# Out:
# ['first']

# %%
unalista[:]
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unalista[1:3] #no incluye a la posición 3
# Out:
# ['second', 'third']

# %%
unalista[-1]
# Out:
# 'sixth'

# %%
unalista[-3:]
# Out:
# ['fourth', 'fifth', 'sixth']

# %%
unalista[-3:-1] #no incluye a la posición -1
# Out:
# ['fourth', 'fifth']
